# %%
import sys
import os
from google.colab import drive
drive.mount('/content/drive')
project_path = '/content/drive/My Drive/CAR_MF'
os.chdir(project_path)
sys.path.append(project_path)
# Out:
# Mounted at /content/drive

# %%
import warnings
warnings.simplefilter("ignore", category=FutureWarning)

# %%
import pandas as pd
import numpy as np
import itertools

# %%
from split_temporal_cv import create_temporal_folds_with_cold_start

# %%
from eval_map_k import map_at_k

# %%
from model_car_mf import CAR_MF
from model_car_mf_bias import CAR_MF_Bias
from model_mf import Standard_MF
from model_mf_bias import Standard_MF_Bias

# %% [markdown]
# # Import data

# %%
df_ml_small = pd.read_csv('./database/ml-latest-small/ratings.csv')
df_ml_small = df_ml_small.rename(columns={'userId':'userid',
                                          'movieId':'itemid',
                                          'rating':'rating'})

# %% [markdown]
# # Set up "Temporal CV"

# %%
train_list_ml_small, test_list_ml_small, cold_start_list_ml_small = \
    create_temporal_folds_with_cold_start(df_ml_small,5)

# %%
train_list = [train_list_ml_small]
test_list = [test_list_ml_small]
cold_list = [cold_start_list_ml_small]

# %% [markdown]
# # Initialize params

# %%
MODEL_REGISTRY = {
    'MF': Standard_MF,
    'MF+Bias': Standard_MF_Bias,
    'CAR_MF': CAR_MF,
    'CAR_MF+Bias': CAR_MF_Bias
}

# %%
dataset_list = ['ml_small']
latent_list = [50]
epoch_list = [100]
learning_rate_list = [0.001]
lambda_rate_list = [0.001]

hyperparameter_grid = list(itertools.product(
    MODEL_REGISTRY.keys(),
    latent_list,
    learning_rate_list,
    lambda_rate_list,
    epoch_list
))

# %% [markdown]
# # Train model

# %%
import pandas as pd

# Assume all your previous setup code is here
# (dataset_list, train_list, test_list, cold_list, hyperparameter_grid, MODEL_REGISTRY, map_at_k)

all_results = [] # 1. Initialize an empty list to store results

for i, dataset_name in enumerate(dataset_list):
    print(f"Data set: {dataset_name}")
    print('===========================================')
    train_list_data = train_list[i]
    test_list_data = test_list[i]
    cold_flag_list_data = cold_list[i]

    # for fold in range(1):
    for fold in range(len(train_list_data)):
        print(f"Fold: {fold + 1}")
        train_array = train_list_data[fold]
        # Your original code had a potential bug here, duplicating test data.
        # Corrected to just use the test set for the fold.
        test_array = test_list_data[fold]
        cold_flag_array = cold_flag_list_data[fold]
        print(f"Shape of data: {train_array.shape}\n")

        for params in hyperparameter_grid:
            model_name, latent, learning_rate, lambda_rate, epoch = params

            print(f"--- Training Model: {model_name} ---")
            print(f"Parameters: K={latent}, LR={learning_rate}, Lambda={lambda_rate}, Epochs={epoch}")

            ModelClass = MODEL_REGISTRY[model_name]
            model_instance = ModelClass(K=latent, learning_rate=learning_rate, lambda_rate=lambda_rate)
            model_instance.fit(Y=train_array, epochs=epoch, batch_size=512)
            results = model_instance.predict()
            pred_array = results['predictions']

            # Unpack the tuple of MAP scores
            map_k, map_k_cold, map_k_not_cold = map_at_k(pred_array, test_array, cold_flag_array, 5)

            print(f"Result -> MAP@5: {map_k:.4f}, Cold: {map_k_cold:.4f}, Not Cold: {map_k_not_cold:.4f}\n")

            # 2. Create a dictionary for the current run and append it to the list
            result_entry = {
                'Dataset': dataset_name,
                'Fold': fold + 1,
                'Model': model_name,
                'K': latent,
                'LR': learning_rate,
                'Lambda': lambda_rate,
                'Epochs': epoch,
                'MAP@5': map_k,
                'MAP@5_cold': map_k_cold,
                'MAP@5_not_cold': map_k_not_cold
            }
            all_results.append(result_entry)

    print('===========================================')
# Out:
# Data set: ml_small
# ===========================================
# Fold: 1
# Shape of data: (610, 9724)
#
# --- Training Model: MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.7062
# Epoch 20/100, Train RMSE: 3.6913
# Epoch 30/100, Train RMSE: 3.6623
# Epoch 40/100, Train RMSE: 3.6171
# Epoch 50/100, Train RMSE: 3.5550
# Epoch 60/100, Train RMSE: 3.4760
# Epoch 70/100, Train RMSE: 3.3804
# Epoch 80/100, Train RMSE: 3.2660
# Epoch 90/100, Train RMSE: 3.1367
# Epoch 100/100, Train RMSE: 2.9888
# Result -> MAP@5: 0.0511, Cold: 0.0417, Not Cold: 0.0647
#
# --- Training Model: MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 1.0443
# Epoch 20/100, Train RMSE: 1.0244
# Epoch 30/100, Train RMSE: 0.9949
# Epoch 40/100, Train RMSE: 0.9554
# Epoch 50/100, Train RMSE: 0.9052
# Epoch 60/100, Train RMSE: 0.8464
# Epoch 70/100, Train RMSE: 0.7825
# Epoch 80/100, Train RMSE: 0.7149
# Epoch 90/100, Train RMSE: 0.6482
# Epoch 100/100, Train RMSE: 0.5824
# Result -> MAP@5: 0.1190, Cold: 0.1329, Not Cold: 0.0985
#
# --- Training Model: CAR_MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.7037
# Epoch 20/100, Train RMSE: 3.6765
# Epoch 30/100, Train RMSE: 3.6155
# Epoch 40/100, Train RMSE: 3.5184
# Epoch 50/100, Train RMSE: 3.3903
# Epoch 60/100, Train RMSE: 3.2337
# Epoch 70/100, Train RMSE: 3.0516
# Epoch 80/100, Train RMSE: 2.8456
# Epoch 90/100, Train RMSE: 2.6182
# Epoch 100/100, Train RMSE: 2.3764
# Result -> MAP@5: 0.0467, Cold: 0.0379, Not Cold: 0.0595
#
# --- Training Model: CAR_MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6604
# Epoch 20/100, Train RMSE: 3.5902
# Epoch 30/100, Train RMSE: 3.4883
# Epoch 40/100, Train RMSE: 3.3488
# Epoch 50/100, Train RMSE: 3.1699
# Epoch 60/100, Train RMSE: 2.9489
# Epoch 70/100, Train RMSE: 2.6884
# Epoch 80/100, Train RMSE: 2.3958
# Epoch 90/100, Train RMSE: 2.0722
# Epoch 100/100, Train RMSE: 1.7355
# Result -> MAP@5: 0.2001, Cold: 0.2297, Not Cold: 0.1567
#
# Fold: 2
# Shape of data: (610, 9724)
#
# --- Training Model: MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6752
# Epoch 20/100, Train RMSE: 3.6602
# Epoch 30/100, Train RMSE: 3.6305
# Epoch 40/100, Train RMSE: 3.5846
# Epoch 50/100, Train RMSE: 3.5205
# Epoch 60/100, Train RMSE: 3.4380
# Epoch 70/100, Train RMSE: 3.3378
# Epoch 80/100, Train RMSE: 3.2187
# Epoch 90/100, Train RMSE: 3.0823
# Epoch 100/100, Train RMSE: 2.9275
# Result -> MAP@5: 0.0562, Cold: 0.0493, Not Cold: 0.0581
#
# --- Training Model: MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 1.0613
# Epoch 20/100, Train RMSE: 1.0408
# Epoch 30/100, Train RMSE: 1.0105
# Epoch 40/100, Train RMSE: 0.9686
# Epoch 50/100, Train RMSE: 0.9145
# Epoch 60/100, Train RMSE: 0.8526
# Epoch 70/100, Train RMSE: 0.7895
# Epoch 80/100, Train RMSE: 0.7260
# Epoch 90/100, Train RMSE: 0.6640
# Epoch 100/100, Train RMSE: 0.6042
# Result -> MAP@5: 0.1894, Cold: 0.2100, Not Cold: 0.1838
#
# --- Training Model: CAR_MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6727
# Epoch 20/100, Train RMSE: 3.6432
# Epoch 30/100, Train RMSE: 3.5767
# Epoch 40/100, Train RMSE: 3.4720
# Epoch 50/100, Train RMSE: 3.3345
# Epoch 60/100, Train RMSE: 3.1673
# Epoch 70/100, Train RMSE: 2.9752
# Epoch 80/100, Train RMSE: 2.7606
# Epoch 90/100, Train RMSE: 2.5261
# Epoch 100/100, Train RMSE: 2.2782
# Result -> MAP@5: 0.1090, Cold: 0.0826, Not Cold: 0.1161
#
# --- Training Model: CAR_MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6291
# Epoch 20/100, Train RMSE: 3.5557
# Epoch 30/100, Train RMSE: 3.4470
# Epoch 40/100, Train RMSE: 3.2964
# Epoch 50/100, Train RMSE: 3.1040
# Epoch 60/100, Train RMSE: 2.8707
# Epoch 70/100, Train RMSE: 2.5993
# Epoch 80/100, Train RMSE: 2.2985
# Epoch 90/100, Train RMSE: 1.9739
# Epoch 100/100, Train RMSE: 1.6447
# Result -> MAP@5: 0.1830, Cold: 0.1880, Not Cold: 0.1817
#
# Fold: 3
# Shape of data: (610, 9724)
#
# --- Training Model: MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6400
# Epoch 20/100, Train RMSE: 3.6247
# Epoch 30/100, Train RMSE: 3.5942
# Epoch 40/100, Train RMSE: 3.5471
# Epoch 50/100, Train RMSE: 3.4821
# Epoch 60/100, Train RMSE: 3.3982
# Epoch 70/100, Train RMSE: 3.2965
# Epoch 80/100, Train RMSE: 3.1757
# Epoch 90/100, Train RMSE: 3.0375
# Epoch 100/100, Train RMSE: 2.8809
# Result -> MAP@5: 0.0268, Cold: 0.0480, Not Cold: 0.0259
#
# --- Training Model: MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 1.0304
# Epoch 20/100, Train RMSE: 1.0107
# Epoch 30/100, Train RMSE: 0.9816
# Epoch 40/100, Train RMSE: 0.9413
# Epoch 50/100, Train RMSE: 0.8898
# Epoch 60/100, Train RMSE: 0.8329
# Epoch 70/100, Train RMSE: 0.7756
# Epoch 80/100, Train RMSE: 0.7193
# Epoch 90/100, Train RMSE: 0.6649
# Epoch 100/100, Train RMSE: 0.6116
# Result -> MAP@5: 0.0252, Cold: 0.1373, Not Cold: 0.0204
#
# --- Training Model: CAR_MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6364
# Epoch 20/100, Train RMSE: 3.6035
# Epoch 30/100, Train RMSE: 3.5302
# Epoch 40/100, Train RMSE: 3.4144
# Epoch 50/100, Train RMSE: 3.2615
# Epoch 60/100, Train RMSE: 3.0761
# Epoch 70/100, Train RMSE: 2.8632
# Epoch 80/100, Train RMSE: 2.6277
# Epoch 90/100, Train RMSE: 2.3736
# Epoch 100/100, Train RMSE: 2.1061
# Result -> MAP@5: 0.1281, Cold: 0.0000, Not Cold: 0.1335
#
# --- Training Model: CAR_MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.5930
# Epoch 20/100, Train RMSE: 3.5192
# Epoch 30/100, Train RMSE: 3.4102
# Epoch 40/100, Train RMSE: 3.2615
# Epoch 50/100, Train RMSE: 3.0730
# Epoch 60/100, Train RMSE: 2.8450
# Epoch 70/100, Train RMSE: 2.5801
# Epoch 80/100, Train RMSE: 2.2868
# Epoch 90/100, Train RMSE: 1.9712
# Epoch 100/100, Train RMSE: 1.6532
# Result -> MAP@5: 0.1798, Cold: 0.2260, Not Cold: 0.1779
#
# Fold: 4
# Shape of data: (610, 9724)
#
# --- Training Model: MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6369
# Epoch 20/100, Train RMSE: 3.6208
# Epoch 30/100, Train RMSE: 3.5881
# Epoch 40/100, Train RMSE: 3.5378
# Epoch 50/100, Train RMSE: 3.4692
# Epoch 60/100, Train RMSE: 3.3816
# Epoch 70/100, Train RMSE: 3.2760
# Epoch 80/100, Train RMSE: 3.1511
# Epoch 90/100, Train RMSE: 3.0085
# Epoch 100/100, Train RMSE: 2.8478
# Result -> MAP@5: 0.0162, Cold: 0.0188, Not Cold: 0.0075
#
# --- Training Model: MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 1.0265
# Epoch 20/100, Train RMSE: 1.0068
# Epoch 30/100, Train RMSE: 0.9778
# Epoch 40/100, Train RMSE: 0.9374
# Epoch 50/100, Train RMSE: 0.8864
# Epoch 60/100, Train RMSE: 0.8312
# Epoch 70/100, Train RMSE: 0.7768
# Epoch 80/100, Train RMSE: 0.7254
# Epoch 90/100, Train RMSE: 0.6751
# Epoch 100/100, Train RMSE: 0.6247
# Result -> MAP@5: 0.0150, Cold: 0.0183, Not Cold: 0.0041
#
# --- Training Model: CAR_MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6325
# Epoch 20/100, Train RMSE: 3.5985
# Epoch 30/100, Train RMSE: 3.5229
# Epoch 40/100, Train RMSE: 3.4042
# Epoch 50/100, Train RMSE: 3.2468
# Epoch 60/100, Train RMSE: 3.0571
# Epoch 70/100, Train RMSE: 2.8397
# Epoch 80/100, Train RMSE: 2.5988
# Epoch 90/100, Train RMSE: 2.3388
# Epoch 100/100, Train RMSE: 2.0643
# Result -> MAP@5: 0.1293, Cold: 0.1262, Not Cold: 0.1392
#
# --- Training Model: CAR_MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.5895
# Epoch 20/100, Train RMSE: 3.5149
# Epoch 30/100, Train RMSE: 3.4058
# Epoch 40/100, Train RMSE: 3.2577
# Epoch 50/100, Train RMSE: 3.0706
# Epoch 60/100, Train RMSE: 2.8445
# Epoch 70/100, Train RMSE: 2.5825
# Epoch 80/100, Train RMSE: 2.2923
# Epoch 90/100, Train RMSE: 1.9814
# Epoch 100/100, Train RMSE: 1.6699
# Result -> MAP@5: 0.2218, Cold: 0.2111, Not Cold: 0.2566
#
# Fold: 5
# Shape of data: (610, 9724)
#
# --- Training Model: MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6662
# Epoch 20/100, Train RMSE: 3.6499
# Epoch 30/100, Train RMSE: 3.6167
# Epoch 40/100, Train RMSE: 3.5657
# Epoch 50/100, Train RMSE: 3.4958
# Epoch 60/100, Train RMSE: 3.4070
# Epoch 70/100, Train RMSE: 3.2997
# Epoch 80/100, Train RMSE: 3.1732
# Epoch 90/100, Train RMSE: 3.0285
# Epoch 100/100, Train RMSE: 2.8655
# Result -> MAP@5: 0.0571, Cold: 0.0761, Not Cold: 0.0479
#
# --- Training Model: MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 1.0214
# Epoch 20/100, Train RMSE: 1.0020
# Epoch 30/100, Train RMSE: 0.9738
# Epoch 40/100, Train RMSE: 0.9335
# Epoch 50/100, Train RMSE: 0.8845
# Epoch 60/100, Train RMSE: 0.8332
# Epoch 70/100, Train RMSE: 0.7826
# Epoch 80/100, Train RMSE: 0.7363
# Epoch 90/100, Train RMSE: 0.6906
# Epoch 100/100, Train RMSE: 0.6425
# Result -> MAP@5: 0.0418, Cold: 0.0530, Not Cold: 0.0364
#
# --- Training Model: CAR_MF ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6606
# Epoch 20/100, Train RMSE: 3.6260
# Epoch 30/100, Train RMSE: 3.5506
# Epoch 40/100, Train RMSE: 3.4301
# Epoch 50/100, Train RMSE: 3.2665
# Epoch 60/100, Train RMSE: 3.0647
# Epoch 70/100, Train RMSE: 2.8336
# Epoch 80/100, Train RMSE: 2.5766
# Epoch 90/100, Train RMSE: 2.2995
# Epoch 100/100, Train RMSE: 2.0064
# Result -> MAP@5: 0.1074, Cold: 0.1263, Not Cold: 0.0982
#
# --- Training Model: CAR_MF+Bias ---
# Parameters: K=50, LR=0.001, Lambda=0.001, Epochs=100
# Epoch 10/100, Train RMSE: 3.6182
# Epoch 20/100, Train RMSE: 3.5429
# Epoch 30/100, Train RMSE: 3.4334
# Epoch 40/100, Train RMSE: 3.2848
# Epoch 50/100, Train RMSE: 3.0977
# Epoch 60/100, Train RMSE: 2.8728
# Epoch 70/100, Train RMSE: 2.6134
# Epoch 80/100, Train RMSE: 2.3264
# Epoch 90/100, Train RMSE: 2.0202
# Epoch 100/100, Train RMSE: 1.7131
# Result -> MAP@5: 0.0947, Cold: 0.0895, Not Cold: 0.0972
#
# ===========================================

# %%
# 3. After all loops, create a DataFrame from the results list
results_df = pd.DataFrame(all_results)

# --- Display the Results ---

# Option 1: Print the full, detailed table for every run
print("\n--- Detailed Results for Each Fold ---")
# Using .to_string() to ensure all rows and columns are displayed
print(results_df.to_string())

# Option 2: Print an aggregated summary (mean and std deviation across folds)
print("\n\n--- Aggregated Summary (Mean & Std Dev over Folds) ---")
summary_df = results_df.groupby(['Dataset', 'Model', 'K', 'LR', 'Lambda', 'Epochs']).agg({
    'MAP@5': ['mean', 'std'],
    'MAP@5_cold': ['mean', 'std'],
    'MAP@5_not_cold': ['mean', 'std']
}).reset_index()

# Clean up the multi-level column names
summary_df.columns = ['_'.join(col).strip('_') for col in summary_df.columns.values]

print(summary_df.to_string())
# Out:
# --- Detailed Results for Each Fold ---
#      Dataset  Fold        Model   K     LR  Lambda  Epochs     MAP@5  MAP@5_cold  MAP@5_not_cold
# 0   ml_small     1           MF  50  0.001   0.001     100  0.051056    0.041722        0.064715
# 1   ml_small     1      MF+Bias  50  0.001   0.001     100  0.118977    0.132944        0.098537
# 2   ml_small     1       CAR_MF  50  0.001   0.001     100  0.046700    0.037944        0.059512
# 3   ml_small     1  CAR_MF+Bias  50  0.001   0.001     100  0.200066    0.229667        0.156748
# 4   ml_small     2           MF  50  0.001   0.001     100  0.056196    0.049259        0.058060
# 5   ml_small     2      MF+Bias  50  0.001   0.001     100  0.189373    0.210000        0.183831
# 6   ml_small     2       CAR_MF  50  0.001   0.001     100  0.109020    0.082593        0.116119
# 7   ml_small     2  CAR_MF+Bias  50  0.001   0.001     100  0.183020    0.187963        0.181692
# 8   ml_small     3           MF  50  0.001   0.001     100  0.026775    0.048000        0.025876
# 9   ml_small     3      MF+Bias  50  0.001   0.001     100  0.025176    0.137333        0.020424
# 10  ml_small     3       CAR_MF  50  0.001   0.001     100  0.128103    0.000000        0.133531
# 11  ml_small     3  CAR_MF+Bias  50  0.001   0.001     100  0.179810    0.226000        0.177853
# 12  ml_small     4           MF  50  0.001   0.001     100  0.016152    0.018830        0.007471
# 13  ml_small     4      MF+Bias  50  0.001   0.001     100  0.014959    0.018298        0.004138
# 14  ml_small     4       CAR_MF  50  0.001   0.001     100  0.129295    0.126241        0.139195
# 15  ml_small     4  CAR_MF+Bias  50  0.001   0.001     100  0.221816    0.211099        0.256552
# 16  ml_small     5           MF  50  0.001   0.001     100  0.057096    0.076061        0.047892
# 17  ml_small     5      MF+Bias  50  0.001   0.001     100  0.041815    0.053030        0.036373
# 18  ml_small     5       CAR_MF  50  0.001   0.001     100  0.107393    0.126263        0.098235
# 19  ml_small     5  CAR_MF+Bias  50  0.001   0.001     100  0.094686    0.089495        0.097206
#
#
# --- Aggregated Summary (Mean & Std Dev over Folds) ---
#     Dataset        Model   K     LR  Lambda  Epochs  MAP@5_mean  MAP@5_std  MAP@5_cold_mean  MAP@5_cold_std  MAP@5_not_cold_mean  MAP@5_not_cold_std
# 0  ml_small       CAR_MF  50  0.001   0.001     100    0.104102   0.033693         0.074608        0.055472             0.109319            0.032127
# 1  ml_small  CAR_MF+Bias  50  0.001   0.001     100    0.175880   0.048358         0.188845        0.057908             0.174010            0.057192
# 2  ml_small           MF  50  0.001   0.001     100    0.041455   0.018774         0.046774        0.020444             0.040803            0.023736
# 3  ml_small      MF+Bias  50  0.001   0.001     100    0.078060   0.074426         0.110321        0.075710             0.068660            0.073636

# %%
summary_df
# Out:
#     Dataset        Model   K     LR  Lambda  Epochs  MAP@5_mean  MAP@5_std  \
# 0  ml_small       CAR_MF  50  0.001   0.001     100    0.104102   0.033693
# 1  ml_small  CAR_MF+Bias  50  0.001   0.001     100    0.175880   0.048358
# 2  ml_small           MF  50  0.001   0.001     100    0.041455   0.018774
# 3  ml_small      MF+Bias  50  0.001   0.001     100    0.078060   0.074426
#
#    MAP@5_cold_mean  MAP@5_cold_std  MAP@5_not_cold_mean  MAP@5_not_cold_std
# 0         0.074608        0.055472             0.109319            0.032127
# 1         0.188845        0.057908             0.174010            0.057192
# 2         0.046774        0.020444             0.040803            0.023736
# 3         0.110321        0.075710             0.068660            0.073636
